# %% [markdown]
# # 基于东易日盛行情数据的基本分布分析
# > v0.1
# >
# > 20160414
# >
# > 主要是涨幅和价格的分析

# %% [markdown]
# 导入模块

# %%
import tushare as ts
import pylab
import pandas as pd
import numpy as np
# %matplotlib inline
code='002713'

# %% [markdown]
# ### 获得基础信息

# %%
bi=ts.get_stock_basics()
name=bi.ix[code].name
st=bi.ix[code].timeToMarket
st=str(st)
starttime=st[:4]+'-'+st[4:6]+'-'+st[6:8]
bi.ix[code]
# Out:
# name                    东易日盛
# industry                装修装饰
# area                      北京
# pe                         0
# outstanding          6241.31
# totals               24968.1
# totalAssets           192768
# liquidAssets          136492
# fixedAssets          11343.5
# reserved               39289
# reservedPerShare        1.57
# esp                    -0.14
# bvps                    3.32
# pb                     10.25
# timeToMarket        20140219
# Name: 002713, dtype: object

# %% [markdown]
# ### 获得近三年的日线数据

# %%
dp=ts.get_hist_data(code)
dp[:5]
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# date
# 2016-04-15  36.30  36.30  35.30  34.98  23291.18         -0.89     -2.46
# 2016-04-14  35.75  36.38  36.19  35.35  25599.58          0.61      1.71
# 2016-04-13  36.10  37.39  35.58  35.57  47478.08         -0.82     -2.25
# 2016-04-12  34.80  38.10  36.40  33.92  45342.65          1.36      3.88
# 2016-04-11  34.61  35.32  35.04  34.61  26553.80          1.02      3.00
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# date
# 2016-04-15  35.702  35.663  36.242  33653.06  39608.41  52451.88      3.73
# 2016-04-14  35.446  35.633  36.237  38574.11  42708.29  55010.57      4.10
# 2016-04-13  35.340  35.648  36.027  41349.44  46076.13  55900.91      7.61
# 2016-04-12  35.642  35.549  35.894  42126.31  47172.89  56914.73      7.26
# 2016-04-11  35.700  35.569  35.651  43294.94  51778.64  57529.86      4.25

# %% [markdown]
# ### 获得涨幅数据列，并绘制涨幅分布图

# %%
pc=dp.p_change
pxt=np.arange(-20,20,1)
pxl=[-20,20]
pc.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
print '最小值：',pc.min()
print '最大值：',pc.max()
print '平均值：',pc.mean()
print '标准差：',pc.std()
# Out:
# 最小值： -10.02
# 最大值： 44.0
# 平均值： 0.350882917466
# 标准差： 4.89978778855

# %% [markdown]
# -
#
# -

# %% [markdown]
# ### 近20日的涨幅数据及分布图

# %%
pc20=dp[:20].p_change
pc.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
pc20.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
print '最小值：',pc20.min()
print '最大值：',pc20.max()
print '平均值：',pc20.mean()
print '标准差：',pc20.std()
# Out:
# 最小值： -5.49
# 最大值： 10.0
# 平均值： 0.098
# 标准差： 4.21729346981

# %% [markdown]
# - 根据月内数据与三年数据的比较，判断近期行情的重心

# %% [markdown]
# ### 分析三年数据的收盘价分布情况

# %%
close=dp.close
cxt=np.arange(0,100,2)
cxl=[0,100]
close.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
print '最小值：',close.min()
print '最大值：',close.max()
print '平均值：',close.mean()
print '标准差：',close.std()
# Out:
# 最小值： 14.0
# 最大值： 88.81
# 平均值： 36.5843761996
# 标准差： 11.60451358

# %% [markdown]
# - 此图基本反应了
#
#  -
#
#  -

# %% [markdown]
# 近20日收盘价分布情况对比

# %%
close20=dp[:20].close
close.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
close20.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
print '最小值：',close20.min()
print '最大值：',close20.max()
print '平均值：',close20.mean()
print '标准差：',close20.std()
# Out:
# 最小值： 34.02
# 最大值： 38.72
# 平均值： 36.2415
# 标准差： 1.28637096638

# %% [markdown]
# 近20日的收盘价数据与三年数据的对比，判断目前价格位置

# %% [markdown]
# ### 对全部数据的收盘价分析

# %% [markdown]
# #### 获取全部数据

# %% [markdown]
# 前复权数据

# %%
dfqfq=ts.get_h_data(code,start=starttime) 
dfqfq[:5]
# Out:
# [Getting data:]#########
#              open   high  close    low     volume       amount
# date
# 2016-04-15  36.30  36.30  35.30  34.98  2329118.0   82469576.0
# 2016-04-14  35.75  36.38  36.19  35.35  2559958.0   91733352.0
# 2016-04-13  36.10  37.39  35.58  35.57  4747808.0  173075184.0
# 2016-04-12  34.80  38.10  36.40  33.92  4534265.0  161006048.0
# 2016-04-11  34.61  35.32  35.04  34.61  2655380.0   92888976.0

# %% [markdown]
# 简单分析

# %%
dfqfq.describe()
# Out:
#              open        high       close         low        volume  \
# count  519.000000  519.000000  519.000000  519.000000  5.190000e+02
# mean    23.960077   24.804605   24.085742   23.245318  2.779307e+06
# std      7.850050    8.232399    7.876464    7.380928  2.347018e+06
# min     12.330000   14.080000   13.810000   12.330000  2.447410e+05
# 25%     17.895000   18.360000   17.990000   17.545000  1.188480e+06
# 50%     22.060000   22.680000   22.260000   21.490000  2.102395e+06
# 75%     27.445000   28.570000   27.745000   26.565000  3.697845e+06
# max     54.550000   57.600000   55.100000   51.510000  2.096234e+07
#
#              amount
# count  5.190000e+02
# mean   9.761222e+07
# std    9.591957e+07
# min    8.738151e+06
# 25%    4.283759e+07
# 50%    7.193477e+07
# 75%    1.206747e+08
# max    9.429279e+08

# %% [markdown]
# 除权数据

# %%
df=ts.get_h_data(code,start=starttime,autype='None') 
df[:5]
# Out:
# [Getting data:]#########
#              open   high  close    low     volume       amount
# date
# 2016-04-15  36.30  36.30  35.30  34.98  2329118.0   82469576.0
# 2016-04-14  35.75  36.38  36.19  35.35  2559958.0   91733352.0
# 2016-04-13  36.10  37.39  35.58  35.57  4747808.0  173075184.0
# 2016-04-12  34.80  38.10  36.40  33.92  4534265.0  161006048.0
# 2016-04-11  34.61  35.32  35.04  34.61  2655380.0   92888976.0

# %% [markdown]
# 简单分析

# %%
df.describe()
# Out:
#              open        high       close         low        volume  \
# count  519.000000  519.000000  519.000000  519.000000  5.190000e+02
# mean    36.389326   37.573931   36.577900   35.394451  2.779307e+06
# std     11.443529   11.762652   11.552161   11.104592  2.347018e+06
# min     14.230000   15.400000   14.000000   13.980000  2.447410e+05
# 25%     28.110000   29.400000   28.455000   27.145000  1.188480e+06
# 50%     35.190000   36.190000   35.280000   34.520000  2.102395e+06
# 75%     43.415000   44.330000   43.450000   42.350000  3.697845e+06
# max     83.770000   88.770000   88.770000   80.410000  2.096234e+07
#
#              amount
# count  5.190000e+02
# mean   9.761222e+07
# std    9.591957e+07
# min    8.738151e+06
# 25%    4.283759e+07
# 50%    7.193477e+07
# 75%    1.206747e+08
# max    9.429279e+08

# %% [markdown]
# #### 收盘价分析

# %% [markdown]
# 前复权收盘价分析

# %%
closeallqfq=dfqfq.close
qxt=np.arange(0,70,1)
qxl=[0,70]
closeallqfq.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)
print ' '
print '最小值：',closeallqfq.min()
print '最大值：',closeallqfq.max()
print '平均值：',closeallqfq.mean()
print '标准差：',closeallqfq.std()
# Out:
#
# 最小值： 13.81
# 最大值： 55.1
# 平均值： 24.0857418112
# 标准差： 7.8764635325

# %% [markdown]
# - 数据是前复权数据，因此最大值和最小值都向下滑动了。特点为：
#
#  -
#
#   -

# %% [markdown]
# 与20日收盘价对比

# %%
closeallqfq20=dfqfq[:20].close
closeallqfq.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)
closeallqfq20.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)

# %% [markdown]
# 除权数据收盘价分析

# %%
closeall=df.close
closeall.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
print '最小值：',closeall.min()
print '最大值：',closeall.max()
print '平均值：',closeall.mean()
print '标准差：',closeall.std()
# Out:
# 最小值： 14.0
# 最大值： 88.77
# 平均值： 36.5778998073
# 标准差： 11.5521607074

# %% [markdown]
# - 除权数据的分析中，价格范围相比三年数据扩大不多。特点为：
#
#  -
#
#  -
#
#   -

# %% [markdown]
# 与20日收盘价对比

# %%
closeall20=df[:20].close
closeall.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
closeall20.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)

# %% [markdown]
# *三个月多阶段对比*

# %%
closeall40=df[20:40].close
closeall60=df[40:60].close
closeall.plot(kind='kde',grid=True,figsize=(16,9))
closeall20.plot(kind='kde',grid=True,figsize=(16,9))
closeall40.plot(kind='kde',grid=True,figsize=(16,9))
closeall60.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)

# %%
closeall20.describe()
# Out:
# count    20.000000
# mean     36.241500
# std       1.286371
# min      34.020000
# 25%      35.235000
# 50%      36.265000
# 75%      37.167500
# max      38.720000
# Name: close, dtype: float64

# %%
closeall40.describe()
# Out:
# count    20.000000
# mean     29.420000
# std       2.754499
# min      23.820000
# 25%      28.607500
# 50%      28.945000
# 75%      31.602500
# max      35.200000
# Name: close, dtype: float64

# %%
closeall60.describe()
# Out:
# count    20.000000
# mean     26.778500
# std       1.508856
# min      24.460000
# 25%      25.520000
# 50%      26.845000
# 75%      27.747500
# max      29.930000
# Name: close, dtype: float64

# %% [markdown]
# ### 三年数据的换手率分析

# %%
turnover=dp.turnover
txt=np.arange(-10,40,1)
txl=[-10,40]
turnover.plot(kind='kde',grid=True,figsize=(16,9),xticks=txt,xlim=txl)
print '最小值：',turnover.min()
print '最大值：',turnover.max()
print '平均值：',turnover.mean()
print '标准差：',turnover.std()
# Out:
# 最小值： 0.03
# 最大值： 67.17
# 平均值： 6.40047984645
# 标准差： 6.18901169258

# %% [markdown]
# ### 三年数据和全部数据的基本统计对比

# %% [markdown]
# - 三年数据：

# %%
dp.describe()
# Out:
#              open        high       close         low         volume  \
# count  521.000000  521.000000  521.000000  521.000000     521.000000
# mean    36.396699   37.578215   36.584376   35.404453   27681.592246
# std     11.493214   11.812274   11.604514   11.158907   23488.138115
# min     14.230000   15.400000   14.000000   13.980000      87.000000
# 25%     28.050000   29.400000   28.420000   27.060000   11856.300000
# 50%     35.190000   36.210000   35.290000   34.530000   20950.070000
# 75%     43.480000   44.400000   43.470000   42.440000   36950.000000
# max     83.800000   88.810000   88.810000   80.440000  209623.390000
#
#        price_change    p_change         ma5        ma10        ma20  \
# count    521.000000  521.000000  521.000000  521.000000  521.000000
# mean       0.113800    0.350883   36.569286   36.574877   36.621470
# std        1.680234    4.899788   11.424701   11.277182   11.025519
# min       -5.050000  -10.020000   15.154000   15.820000   16.020000
# 25%       -0.840000   -2.410000   28.162000   27.915000   27.746000
# 50%        0.190000    0.550000   35.438000   35.404000   35.085000
# 75%        0.980000    2.860000   43.570000   43.211000   42.601000
# max        9.240000   44.000000   76.254000   70.517000   62.986000
#
#                v_ma5         v_ma10        v_ma20    turnover
# count     521.000000     521.000000    521.000000  521.000000
# mean    27595.870058   27645.104760  27922.940595    6.400480
# std     20077.862825   18155.837557  17286.849834    6.189012
# min      4551.830000    5885.510000   6812.460000    0.030000
# 25%     12798.900000   13499.910000  13877.580000    3.270000
# 50%     22292.480000   23250.330000  25092.660000    4.720000
# 75%     37783.060000   38364.990000  37892.130000    7.870000
# max    162913.700000  113974.200000  97700.370000   67.170000

# %% [markdown]
# - 全部前复权数据：

# %%
df.describe()
# Out:
#              open        high       close         low        volume  \
# count  519.000000  519.000000  519.000000  519.000000  5.190000e+02
# mean    36.389326   37.573931   36.577900   35.394451  2.779307e+06
# std     11.443529   11.762652   11.552161   11.104592  2.347018e+06
# min     14.230000   15.400000   14.000000   13.980000  2.447410e+05
# 25%     28.110000   29.400000   28.455000   27.145000  1.188480e+06
# 50%     35.190000   36.190000   35.280000   34.520000  2.102395e+06
# 75%     43.415000   44.330000   43.450000   42.350000  3.697845e+06
# max     83.770000   88.770000   88.770000   80.410000  2.096234e+07
#
#              amount
# count  5.190000e+02
# mean   9.761222e+07
# std    9.591957e+07
# min    8.738151e+06
# 25%    4.283759e+07
# 50%    7.193477e+07
# 75%    1.206747e+08
# max    9.429279e+08
