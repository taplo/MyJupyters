# %% [markdown]
# # 基于西藏珠峰行情数据的基本分布分析
# > v0.1
# >
# > 20160418
# >
# > 主要是涨幅和价格的分析

# %% [markdown]
# 导入模块

# %%
import tushare as ts
import pylab
import pandas as pd
import numpy as np
# %matplotlib inline
code='600338'

# %% [markdown]
# ### 获得基础信息

# %%
bi=ts.get_stock_basics()
name=bi.ix[code].name
st=bi.ix[code].timeToMarket
st=str(st)
starttime=st[:4]+'-'+st[4:6]+'-'+st[6:8]
bi.ix[code]
# Out:
# name                    西藏珠峰
# industry                  铅锌
# area                      西藏
# pe                     57.58
# outstanding          15833.3
# totals               65300.7
# totalAssets           136326
# liquidAssets         58631.2
# fixedAssets          66142.2
# reserved             2236.43
# reservedPerShare        0.03
# esp                    0.345
# bvps                    1.29
# pb                     20.55
# timeToMarket        20001227
# Name: 600338, dtype: object

# %% [markdown]
# ### 获得近三年的日线数据

# %%
dp=ts.get_hist_data(code)
dp[:5]
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2016-04-15  24.58  27.45  26.45  24.58  140462.20          1.45      5.80
# 2016-04-14  25.50  25.77  24.98  24.18  120827.76          0.01      0.04
# 2016-04-13  24.75  25.81  24.96  24.40  179818.78          1.50      6.39
# 2016-04-12  23.06  23.83  23.45  23.05   62911.88          0.16      0.69
# 2016-04-11  22.50  23.89  23.30  22.50  106084.66          1.00      4.48
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# date
# 2016-04-15  24.628  23.808  22.088  122021.06  114556.29  113665.90      8.87
# 2016-04-14  23.796  23.528  21.663  111481.54  114659.19  109915.98      7.63
# 2016-04-13  23.272  23.248  21.279  103352.13  117697.01  106730.14     11.36
# 2016-04-12  22.920  22.812  20.931   90500.74  113592.38  101357.17      3.97
# 2016-04-11  22.902  22.435  20.696  102595.13  116913.01  102454.01      6.70

# %% [markdown]
# ### 获得涨幅数据列，并绘制涨幅分布图

# %%
pc=dp.p_change
pxt=np.arange(-20,20,1)
pxl=[-20,20]
pc.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
print '最小值：',pc.min()
print '最大值：',pc.max()
print '平均值：',pc.mean()
print '标准差：',pc.std()
# Out:
# 最小值： -10.04
# 最大值： 10.05
# 平均值： 0.235271659325
# 标准差： 4.11824701691

# %% [markdown]
# -
#
# -

# %% [markdown]
# ### 近20日的涨幅数据及分布图

# %%
pc20=dp[:20].p_change
pc.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
pc20.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
print '最小值：',pc20.min()
print '最大值：',pc20.max()
print '平均值：',pc20.mean()
print '标准差：',pc20.std()
# Out:
# 最小值： -4.2
# 最大值： 8.2
# 平均值： 2.023
# 标准差： 3.75460433125

# %% [markdown]
# - 根据月内数据与三年数据的比较，判断近期行情的重心

# %% [markdown]
# ### 分析三年数据的收盘价分布情况

# %%
close=dp.close
maxi=10*(close.max()//10+1)
cxt=np.arange(0,maxi,1)
cxl=[0,maxi]
close.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
print '最小值：',close.min()
print '最大值：',close.max()
print '平均值：',close.mean()
print '标准差：',close.std()
# Out:
# 最小值： 7.07
# 最大值： 42.38
# 平均值： 14.2461674009
# 标准差： 6.51155896407

# %% [markdown]
# - 此图基本反应了
#
#  -
#
#  -

# %% [markdown]
# 近20日收盘价分布情况对比

# %%
close20=dp[:20].close
close.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
close20.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
print '最小值：',close20.min()
print '最大值：',close20.max()
print '平均值：',close20.mean()
print '标准差：',close20.std()
# Out:
# 最小值： 19.15
# 最大值： 26.45
# 平均值： 22.088
# 标准差： 2.21344361382

# %% [markdown]
# 近20日的收盘价数据与三年数据的对比，判断目前价格位置

# %% [markdown]
# ### 对全部数据的收盘价分析

# %% [markdown]
# #### 获取全部数据

# %% [markdown]
# 前复权数据

# %%
dfqfq=ts.get_h_data(code,start=starttime) 
dfqfq[:5]
# Out:
# [Getting data:]##############################################################
#              open   high  close    low    volume     amount
# date
# 2016-04-15  24.58  27.45  26.47  24.58  14046220  367731532
# 2016-04-14  25.50  25.77  25.00  24.18  12082776  302164388
# 2016-04-13  24.75  25.81  24.97  24.40  17981878  454165190
# 2016-04-12  23.06  23.83  23.46  23.05   6291188  147262039
# 2016-04-11  22.50  23.89  23.29  22.50  10608466  247437870

# %% [markdown]
# 简单分析

# %%
dfqfq.describe()
# Out:
#               open         high        close          low           volume  \
# count  3279.000000  3279.000000  3279.000000  3279.000000      3279.000000
# mean      9.324876     9.555145     9.348344     9.123303   2571776.761513
# std       5.530314     5.734246     5.564987     5.375000   3432352.466134
# min       1.770000     1.860000     1.820000     1.770000     15800.000000
# 25%       4.590000     4.700000     4.615000     4.500000    546312.000000
# 50%       8.550000     8.700000     8.550000     8.400000   1393300.000000
# 75%      12.930000    13.230000    12.955000    12.620000   3056185.500000
# max      41.800000    43.200000    42.380000    40.110000  32964773.000000
#
#              amount
# count  3.279000e+03
# mean   3.525831e+07
# std    7.036928e+07
# min    8.024500e+04
# 25%    3.520844e+06
# 50%    1.248243e+07
# 75%    3.320192e+07
# max    8.007031e+08

# %% [markdown]
# 除权数据

# %%
df=ts.get_h_data(code,start=starttime,autype='None') 
df[:5]
# Out:
# [Getting data:]##############################################################
#              open   high  close    low    volume     amount
# date
# 2016-04-15  24.57  27.44  26.46  24.57  14046220  367731532
# 2016-04-14  25.49  25.76  24.99  24.17  12082776  302164388
# 2016-04-13  24.74  25.80  24.96  24.39  17981878  454165190
# 2016-04-12  23.05  23.82  23.45  23.04   6291188  147262039
# 2016-04-11  22.49  23.88  23.28  22.49  10608466  247437870

# %% [markdown]
# 简单分析

# %%
df.describe()
# Out:
#               open         high        close          low           volume  \
# count  3279.000000  3279.000000  3279.000000  3279.000000      3279.000000
# mean      9.965523    10.207691     9.989061     9.752598   2571776.761513
# std       5.689484     5.883001     5.720391     5.541076   3432352.466134
# min       2.210000     2.320000     2.270000     2.200000     15800.000000
# 25%       5.200000     5.345000     5.240000     5.100000    546312.000000
# 50%       8.920000     9.170000     8.930000     8.770000   1393300.000000
# 75%      13.280000    13.515000    13.300000    13.015000   3056185.500000
# max      41.780000    43.180000    42.360000    40.090000  32964773.000000
#
#              amount
# count  3.279000e+03
# mean   3.525831e+07
# std    7.036928e+07
# min    8.024500e+04
# 25%    3.520844e+06
# 50%    1.248243e+07
# 75%    3.320192e+07
# max    8.007031e+08

# %% [markdown]
# #### 收盘价分析

# %% [markdown]
# 前复权收盘价分析

# %%
closeallqfq=dfqfq.close
qxt=np.arange(0,50,1)
qxl=[0,50]
closeallqfq.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)
print ' '
print '最小值：',closeallqfq.min()
print '最大值：',closeallqfq.max()
print '平均值：',closeallqfq.mean()
print '标准差：',closeallqfq.std()
# Out:
#
# 最小值： 1.82
# 最大值： 42.38
# 平均值： 9.34834400732
# 标准差： 5.5649870014

# %% [markdown]
# - 数据是前复权数据，因此最大值和最小值都向下滑动了。特点为：
#
#  -
#
#   -

# %% [markdown]
# 与20日收盘价对比

# %%
closeallqfq20=dfqfq[:20].close
closeallqfq.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)
closeallqfq20.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)

# %% [markdown]
# 除权数据收盘价分析

# %%
closeall=df.close
nxt=np.arange(0,50,1)
nxl=[0,50]
closeall.plot(kind='kde',grid=True,figsize=(16,9),xticks=nxt,xlim=nxl)
print '最小值：',closeall.min()
print '最大值：',closeall.max()
print '平均值：',closeall.mean()
print '标准差：',closeall.std()
# Out:
# 最小值： 2.27
# 最大值： 42.36
# 平均值： 9.98906068923
# 标准差： 5.72039051952

# %% [markdown]
# - 除权数据的分析中，价格范围相比三年数据扩大不多。特点为：
#
#  -
#
#  -
#
#   -

# %% [markdown]
# 与20日收盘价对比

# %%
closeall20=df[:20].close
closeall.plot(kind='kde',grid=True,figsize=(16,9))
closeall20.plot(kind='kde',grid=True,figsize=(16,9),xticks=nxt,xlim=nxl)

# %% [markdown]
# *三个月多阶段对比*

# %%
closeall40=df[20:40].close
closeall60=df[40:60].close
closeall.plot(kind='kde',grid=True,figsize=(16,9))
closeall20.plot(kind='kde',grid=True,figsize=(16,9))
closeall40.plot(kind='kde',grid=True,figsize=(16,9))
closeall60.plot(kind='kde',grid=True,figsize=(16,9),xticks=nxt,xlim=nxl)

# %%
closeall20.describe()
# Out:
# count    20.000000
# mean     22.080500
# std       2.219074
# min      19.150000
# 25%      19.900000
# 50%      22.310000
# 75%      23.492500
# max      26.460000
# Name: close, dtype: float64

# %%
closeall40.describe()
# Out:
# count    20.00000
# mean     17.73650
# std       1.33669
# min      14.58000
# 25%      17.17250
# 50%      17.95500
# 75%      18.60500
# max      19.90000
# Name: close, dtype: float64

# %%
closeall60.describe()
# Out:
# count    20.000000
# mean     15.491000
# std       1.609884
# min      13.340000
# 25%      14.300000
# 50%      15.065000
# 75%      15.995000
# max      18.790000
# Name: close, dtype: float64

# %% [markdown]
# ### 三年数据的换手率分析

# %%
turnover=dp.turnover
txt=np.arange(-10,40,1)
txl=[-10,40]
turnover.plot(kind='kde',grid=True,figsize=(16,9),xticks=txt,xlim=txl)
print '最小值：',turnover.min()
print '最大值：',turnover.max()
print '平均值：',turnover.mean()
print '标准差：',turnover.std()
# Out:
# 最小值： 0.04
# 最大值： 20.82
# 平均值： 3.9207195301
# 标准差： 3.18609708398

# %% [markdown]
# ### 三年数据和全部数据的基本统计对比

# %% [markdown]
# - 三年数据：

# %%
dp.describe()
# Out:
#              open        high       close         low         volume  \
# count  681.000000  681.000000  681.000000  681.000000     681.000000
# mean    14.164332   14.638253   14.246167   13.800220   62077.153142
# std      6.415287    6.828672    6.511559    6.129967   50448.711763
# min      6.990000    7.530000    7.070000    6.900000     635.000000
# 25%      8.700000    8.900000    8.730000    8.550000   26259.820000
# 50%     12.620000   13.120000   12.700000   12.240000   44323.910000
# 75%     18.010000   18.530000   17.990000   17.500000   83900.400000
# max     41.800000   43.200000   42.380000   40.110000  329647.720000
#
#        price_change    p_change         ma5        ma10        ma20  \
# count    681.000000  681.000000  681.000000  681.000000  681.000000
# mean       0.025492    0.235272   14.201076   14.151862   14.062072
# std        0.775101    4.118247    6.443001    6.372810    6.228525
# min       -3.430000  -10.040000    7.510000    7.675000    7.753000
# 25%       -0.210000   -1.780000    8.686000    8.649000    8.617000
# 50%        0.020000    0.240000   12.754000   12.815000   13.086000
# 75%        0.240000    2.040000   18.248000   17.655000   17.616000
# max        3.330000   10.050000   39.530000   37.696000   35.514000
#
#                v_ma5         v_ma10         v_ma20    turnover
# count     681.000000     681.000000     681.000000  681.000000
# mean    61749.495272   61481.636050   60964.397651    3.920720
# std     42072.735797   38539.691336   35541.565741    3.186097
# min     11402.060000   13360.280000   15601.650000    0.040000
# 25%     29889.750000   31331.090000   31672.240000    1.660000
# 50%     48945.280000   48224.210000   50272.160000    2.800000
# 75%     86526.300000   86882.540000   81861.870000    5.300000
# max    260152.580000  201161.130000  176735.250000   20.820000

# %% [markdown]
# - 全部前复权数据：

# %%
df.describe()
# Out:
#               open         high        close          low           volume  \
# count  3279.000000  3279.000000  3279.000000  3279.000000      3279.000000
# mean      9.965523    10.207691     9.989061     9.752598   2571776.761513
# std       5.689484     5.883001     5.720391     5.541076   3432352.466134
# min       2.210000     2.320000     2.270000     2.200000     15800.000000
# 25%       5.200000     5.345000     5.240000     5.100000    546312.000000
# 50%       8.920000     9.170000     8.930000     8.770000   1393300.000000
# 75%      13.280000    13.515000    13.300000    13.015000   3056185.500000
# max      41.780000    43.180000    42.360000    40.090000  32964773.000000
#
#              amount
# count  3.279000e+03
# mean   3.525831e+07
# std    7.036928e+07
# min    8.024500e+04
# 25%    3.520844e+06
# 50%    1.248243e+07
# 75%    3.320192e+07
# max    8.007031e+08
