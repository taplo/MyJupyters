# %% [markdown]
# # 基于佰利联行情数据的基本分布分析
# > v0.1
# >
# > 20160414
# >
# > 主要是涨幅和价格的分析

# %% [markdown]
# 导入模块

# %%
import tushare as ts
import pylab
import pandas as pd
import numpy as np
# %matplotlib inline
code='002601'

# %% [markdown]
# ### 获得基础信息

# %%
bi=ts.get_stock_basics()
name=bi.ix[code].name
st=bi.ix[code].timeToMarket
st=str(st)
starttime=st[:4]+'-'+st[4:6]+'-'+st[6:8]
bi.ix[code]
# Out:
# name                     佰利联
# industry                化工原料
# area                      河南
# pe                    101.39
# outstanding          16451.3
# totals               20442.4
# totalAssets           576104
# liquidAssets          212005
# fixedAssets           193292
# reserved              140450
# reservedPerShare        6.87
# esp                     0.57
# bvps                   11.24
# pb                      4.92
# timeToMarket        20110715
# Name: 002601, dtype: object

# %% [markdown]
# ### 获得近三年的日线数据

# %%
dp=ts.get_hist_data(code)
dp[:5]
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2016-04-15  55.50  56.19  55.27  54.14  163619.41         -0.96     -1.71
# 2016-04-14  53.90  56.34  56.23  52.50  235788.80          1.93      3.55
# 2016-04-13  54.61  56.47  54.30  53.71  183270.28         -0.74     -1.34
# 2016-04-12  60.45  60.50  55.04  55.04  216029.95         -6.11     -9.99
# 2016-04-11  61.35  62.35  61.15  59.30  159110.05          0.78      1.29
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# date
# 2016-04-15  56.398  59.282  56.186  191563.70  197614.21  204585.62      9.95
# 2016-04-14  57.418  59.557  55.748  198116.61  212238.62  203461.62     14.33
# 2016-04-13  58.812  59.621  55.125  188451.54  210511.87  197123.77     11.14
# 2016-04-12  60.784  59.361  54.648  191340.78  209059.77  194608.31     13.13
# 2016-04-11  62.096  59.212  54.196  186269.76  206921.84  192566.54      9.67

# %% [markdown]
# ### 获得涨幅数据列，并绘制涨幅分布图

# %%
pc=dp.p_change
pxt=np.arange(-20,20,1)
pxl=[-20,20]
pc.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
print '最小值：',pc.min()
print '最大值：',pc.max()
print '平均值：',pc.mean()
print '标准差：',pc.std()
# Out:
# 最小值： -10.01
# 最大值： 10.02
# 平均值： 0.225535714286
# 标准差： 3.68242128744

# %% [markdown]
# -
#
# -

# %% [markdown]
# ### 近20日的涨幅数据及分布图

# %%
pc20=dp[:20].p_change
pc.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
pc20.plot(kind='kde',grid=True,figsize=(16,9),xticks=pxt,xlim=pxl)
print '最小值：',pc20.min()
print '最大值：',pc20.max()
print '平均值：',pc20.mean()
print '标准差：',pc20.std()
# Out:
# 最小值： -9.99
# 最大值： 10.0
# 平均值： 0.972
# 标准差： 4.71005821844

# %% [markdown]
# - 根据月内数据与三年数据的比较，判断近期行情的重心

# %% [markdown]
# ### 分析三年数据的收盘价分布情况

# %%
close=dp.close
cxt=np.arange(0,80,1)
cxl=[0,80]
close.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
print '最小值：',close.min()
print '最大值：',close.max()
print '平均值：',close.mean()
print '标准差：',close.std()
# Out:
# 最小值： 15.16
# 最大值： 64.16
# 平均值： 25.6016815476
# 标准差： 9.99020165266

# %% [markdown]
# - 此图基本反应了
#
#  -
#
#  -

# %% [markdown]
# 近20日收盘价分布情况对比

# %%
close20=dp[:20].close
close.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
close20.plot(kind='kde',grid=True,figsize=(16,9),xticks=cxt,xlim=cxl)
print '最小值：',close20.min()
print '最大值：',close20.max()
print '平均值：',close20.mean()
print '标准差：',close20.std()
# Out:
# 最小值： 48.25
# 最大值： 64.16
# 平均值： 56.1855
# 标准差： 4.60263480034

# %% [markdown]
# 近20日的收盘价数据与三年数据的对比，判断目前价格位置

# %% [markdown]
# ### 对全部数据的收盘价分析

# %% [markdown]
# #### 获取全部数据

# %% [markdown]
# 前复权数据

# %%
dfqfq=ts.get_h_data(code,start=starttime) 
dfqfq[:5]
# Out:
# [Getting data:]###################
#              open   high  close    low      volume        amount
# date
# 2016-04-15  55.50  56.19  55.27  54.14  16361941.0  9.008026e+08
# 2016-04-14  53.90  56.34  56.23  52.50  23578880.0  1.287532e+09
# 2016-04-13  54.61  56.47  54.30  53.71  18327028.0  1.010434e+09
# 2016-04-12  60.45  60.50  55.04  55.04  21602996.0  1.220126e+09
# 2016-04-11  61.35  62.35  61.15  59.30  15911004.0  9.699847e+08

# %% [markdown]
# 简单分析

# %%
dfqfq.describe()
# Out:
#               open         high        close          low        volume  \
# count  1088.000000  1088.000000  1088.000000  1088.000000  1.088000e+03
# mean     29.845230    30.644173    29.914816    29.197831  4.135278e+06
# std      12.284786    12.754448    12.316912    11.910166  3.872045e+06
# min      14.980000    15.230000    15.080000    14.830000  1.498800e+04
# 25%      20.190000    20.657500    20.210000    19.870000  1.679881e+06
# 50%      24.435000    25.045000    24.540000    24.085000  2.906334e+06
# 75%      39.960000    40.707500    40.112500    38.852500  5.140426e+06
# max      64.000000    65.600000    64.160000    62.190000  3.098635e+07
#
#              amount
# count  1.088000e+03
# mean   1.571384e+08
# std    1.996832e+08
# min    7.336630e+05
# 25%    4.817395e+07
# 50%    9.335980e+07
# 75%    1.842924e+08
# max    1.812945e+09

# %% [markdown]
# 除权数据

# %%
df=ts.get_h_data(code,start=starttime,autype='None') 
df[:5]
# Out:
# [Getting data:]###################
#              open   high  close    low      volume        amount
# date
# 2016-04-15  55.50  56.19  55.27  54.14  16361941.0  9.008026e+08
# 2016-04-14  53.90  56.34  56.23  52.50  23578880.0  1.287532e+09
# 2016-04-13  54.61  56.47  54.30  53.71  18327028.0  1.010434e+09
# 2016-04-12  60.45  60.50  55.04  55.04  21602996.0  1.220126e+09
# 2016-04-11  61.35  62.35  61.15  59.30  15911004.0  9.699847e+08

# %% [markdown]
# 简单分析

# %%
df.describe()
# Out:
#               open         high        close          low        volume  \
# count  1088.000000  1088.000000  1088.000000  1088.000000  1.088000e+03
# mean     40.855864    41.938851    40.950671    39.985450  4.135278e+06
# std      30.781175    31.667194    30.866856    30.112046  3.872045e+06
# min      15.060000    15.320000    15.160000    14.910000  1.498800e+04
# 25%      20.300000    20.780000    20.400000    20.015000  1.679881e+06
# 50%      24.705000    25.280000    24.735000    24.310000  2.906334e+06
# 75%      48.715000    49.395000    48.425000    46.207500  5.140426e+06
# max     129.000000   133.300000   129.000000   125.700000  3.098635e+07
#
#              amount
# count  1.088000e+03
# mean   1.571384e+08
# std    1.996832e+08
# min    7.336630e+05
# 25%    4.817395e+07
# 50%    9.335980e+07
# 75%    1.842924e+08
# max    1.812945e+09

# %% [markdown]
# #### 收盘价分析

# %% [markdown]
# 前复权收盘价分析

# %%
closeallqfq=dfqfq.close
qxt=np.arange(0,80,1)
qxl=[0,80]
closeallqfq.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)
print ' '
print '最小值：',closeallqfq.min()
print '最大值：',closeallqfq.max()
print '平均值：',closeallqfq.mean()
print '标准差：',closeallqfq.std()
# Out:
#
# 最小值： 15.08
# 最大值： 64.16
# 平均值： 29.9148161765
# 标准差： 12.3169120972

# %% [markdown]
# - 数据是前复权数据，因此最大值和最小值都向下滑动了。特点为：
#
#  -
#
#   -

# %% [markdown]
# 与20日收盘价对比

# %%
closeallqfq20=dfqfq[:20].close
closeallqfq.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)
closeallqfq20.plot(kind='kde',grid=True,figsize=(16,9),xticks=qxt,xlim=qxl)

# %% [markdown]
# 除权数据收盘价分析

# %%
closeall=df.close
nxt=np.arange(0,150,2)
nxl=[0,150]
closeall.plot(kind='kde',grid=True,figsize=(16,9),xticks=nxt,xlim=nxl)
print '最小值：',closeall.min()
print '最大值：',closeall.max()
print '平均值：',closeall.mean()
print '标准差：',closeall.std()
# Out:
# 最小值： 15.16
# 最大值： 129.0
# 平均值： 40.9506709559
# 标准差： 30.8668564433

# %% [markdown]
# - 除权数据的分析中，价格范围相比三年数据扩大不多。特点为：
#
#  -
#
#  -
#
#   -

# %% [markdown]
# 与20日收盘价对比

# %%
closeall20=df[:20].close
closeall.plot(kind='kde',grid=True,figsize=(16,9))
closeall20.plot(kind='kde',grid=True,figsize=(16,9),xticks=nxt,xlim=nxl)

# %% [markdown]
# *三个月多阶段对比*

# %%
closeall40=df[20:40].close
closeall60=df[40:60].close
closeall.plot(kind='kde',grid=True,figsize=(16,9))
closeall20.plot(kind='kde',grid=True,figsize=(16,9))
closeall40.plot(kind='kde',grid=True,figsize=(16,9))
closeall60.plot(kind='kde',grid=True,figsize=(16,9),xticks=nxt,xlim=nxl)

# %%
closeall20.describe()
# Out:
# count    20.000000
# mean     56.185500
# std       4.602635
# min      48.250000
# 25%      53.135000
# 50%      55.535000
# 75%      60.565000
# max      64.160000
# Name: close, dtype: float64

# %%
closeall40.describe()
# Out:
# count    20.000000
# mean     43.048000
# std       2.799398
# min      37.220000
# 25%      41.265000
# 50%      43.380000
# 75%      45.077500
# max      47.500000
# Name: close, dtype: float64

# %%
closeall60.describe()
# Out:
# count    20.000000
# mean     37.356000
# std       2.950112
# min      31.940000
# 25%      35.280000
# 50%      37.810000
# 75%      39.400000
# max      42.150000
# Name: close, dtype: float64

# %% [markdown]
# ### 三年数据的换手率分析

# %%
turnover=dp.turnover
txt=np.arange(-10,40,1)
txl=[-10,40]
turnover.plot(kind='kde',grid=True,figsize=(16,9),xticks=txt,xlim=txl)
print '最小值：',turnover.min()
print '最大值：',turnover.max()
print '平均值：',turnover.mean()
print '标准差：',turnover.std()
# Out:
# 最小值： 0.01
# 最大值： 18.84
# 平均值： 3.39248511905
# 标准差： 2.59386952075

# %% [markdown]
# ### 三年数据和全部数据的基本统计对比

# %% [markdown]
# - 三年数据：

# %%
dp.describe()
# Out:
#              open        high       close         low         volume  \
# count  672.000000  672.000000  672.000000  672.000000     672.000000
# mean    25.522054   26.252500   25.601682   24.936295   50312.509464
# std      9.976221   10.492305    9.990202    9.513792   43501.399503
# min     15.060000   15.320000   15.160000   14.910000     149.880000
# 25%     18.085000   18.490000   18.157500   17.857500   22187.807500
# 50%     21.735000   22.270000   21.800000   21.385000   37385.905000
# 75%     29.545000   30.525000   29.757500   29.020000   63200.270000
# max     64.000000   65.600000   64.160000   62.190000  309863.530000
#
#        price_change    p_change         ma5        ma10        ma20  \
# count    672.000000  672.000000  672.000000  672.000000  672.000000
# mean       0.054107    0.225536   25.497246   25.352423   25.066430
# std        1.272814    3.682421    9.784660    9.471711    8.857803
# min       -6.110000  -10.010000   15.624000   15.717000   15.882000
# 25%       -0.350000   -1.522500   18.202000   18.177500   18.310250
# 50%        0.060000    0.295000   21.760000   21.773500   21.738000
# 75%        0.412500    1.982500   29.689500   29.581250   29.220000
# max        5.390000   10.020000   62.166000   59.621000   56.186000
#
#                v_ma5         v_ma10         v_ma20    turnover
# count     672.000000     672.000000     672.000000  672.000000
# mean    49780.244851   49136.873080   47701.645759    3.392485
# std     38748.385445   36395.622805   32358.017628    2.593870
# min       450.260000    8479.430000   12036.530000    0.010000
# 25%     24291.767500   26460.537500   27818.147500    1.720000
# 50%     40509.550000   41017.100000   41973.545000    2.670000
# 75%     60205.860000   58918.027500   55163.927500    4.130000
# max    232572.200000  221915.920000  204585.620000   18.840000

# %% [markdown]
# - 全部前复权数据：

# %%
df.describe()
# Out:
#               open         high        close          low        volume  \
# count  1088.000000  1088.000000  1088.000000  1088.000000  1.088000e+03
# mean     40.855864    41.938851    40.950671    39.985450  4.135278e+06
# std      30.781175    31.667194    30.866856    30.112046  3.872045e+06
# min      15.060000    15.320000    15.160000    14.910000  1.498800e+04
# 25%      20.300000    20.780000    20.400000    20.015000  1.679881e+06
# 50%      24.705000    25.280000    24.735000    24.310000  2.906334e+06
# 75%      48.715000    49.395000    48.425000    46.207500  5.140426e+06
# max     129.000000   133.300000   129.000000   125.700000  3.098635e+07
#
#              amount
# count  1.088000e+03
# mean   1.571384e+08
# std    1.996832e+08
# min    7.336630e+05
# 25%    4.817395e+07
# 50%    9.335980e+07
# 75%    1.842924e+08
# max    1.812945e+09
